# %%
# eyball the data

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import ttest_rel
import pingouin as pg

df = pd.read_csv('data/2019-dep.csv')
pd.set_option('display.max_columns', None)
df
# Out:
#    Postcode Postcode Status  LSOA code                LSOA Name  \
# 0  DE24 8AH            Live  E01013591     Derby 026F E01013591
# 1  BN11 2NF            Live  E01031835  Worthing 011E E01031835
#
#    Index of Multiple Deprivation Rank  Index of Multiple Deprivation Decile  \
# 0                                1208                                     1
# 1                               15307                                     5
#
#    Income Rank  Income Decile  Income Score  Employment Rank  \
# 0          704              1         0.371             3391
# 1        17292              6         0.094            12489
#
#    Employment Decile  Employment Score  Education and Skills Rank  \
# 0                  2             0.195                        802
# 1                  4             0.100                      17187
#
#    Education and Skills Decile  Health and Disability Rank  \
# 0                            1                        1255
# 1                            6                       14075
#
#    Health and Disability Decile  Crime Rank  Crime Decile  \
# 0                             1       14401             5
# 1                             5       21823             7
#
#    Barriers to Housing and Services Rank  \
# 0                                  15995
# 1                                  22242
#
#    Barriers to Housing and Services Decile  Living Environment Rank  \
# 0                                        5                     1908
# 1                                        7                     3574
#
#    Living Environment Decile  IDACI Rank  IDACI Decile  IDACI Score  \
# 0                          1         370             1        0.492
# 1                          2       24124             8        0.069
#
#    IDAOPI Rank  IDAOPI Decile  IDAOPI Score
# 0         3418              2         0.336
# 1        15361              5         0.137
