# %% [markdown]
# ## A page using the palmer penguins dataset to look at various SK learn property's

# %%
#importing all the nessesary items

import pandas as pd
import seaborn as sns 
from palmerpenguins import load_penguins
import sklearn.neighbors as nei

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split



sns.set_style('whitegrid')
penguins = load_penguins()
# displaying the origional data set
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
# setting up a box plot to display body mass, location and species

g = sns.boxplot(x = 'island',
            y ='body_mass_g',
            hue = 'species',
            data = penguins,
            palette=['#FF8C00','#159090','#A034F0'],
            linewidth=0.3)
g.set_xlabel('Island')
g.set_ylabel('Body Mass')
# Out:
# Text(0, 0.5, 'Body Mass')

# %% [markdown]
# ## Setting various different sets for use

# %%
penguins2= penguins[['species','bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']]

# %%
penguins3=penguins[['species','bill_length_mm','bill_depth_mm']]

# %%
penguins4= penguins[['flipper_length_mm','body_mass_g']]

# %%
penguins5 =penguins.loc[penguins.loc[:,'bill_length_mm']>0]

# %%
penguins5
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
# showing female only penguins
penguins6 = penguins.loc[penguins.loc[:,'sex']== "female"]

# %%
penguins6
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 6       Adelie  Torgersen            38.9           17.8              181.0
# 12      Adelie  Torgersen            41.1           17.6              182.0
# ..         ...        ...             ...            ...                ...
# 335  Chinstrap      Dream            45.6           19.4              194.0
# 337  Chinstrap      Dream            46.8           16.5              189.0
# 338  Chinstrap      Dream            45.7           17.0              195.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
#using the dropna command to remove all NaN values from thr table
penguins7=penguins.dropna()

# %%
penguins7
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins7['flipper_length_mm']
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 4      193.0
# 5      190.0
#        ...
# 339    207.0
# 340    202.0
# 341    193.0
# 342    210.0
# 343    198.0
# Name: flipper_length_mm, Length: 333, dtype: float64

# %%
# lmplot produces regression plots across different sub sectors

g = sns.lmplot(x="flipper_length_mm",
               y="body_mass_g",
               hue="species",
               height=7,
               data=penguins,
               palette=['#FF8C00','#159090','#A034F0'])
g.set_xlabels('Flipper Length')
g.set_ylabels('Body Mass')

# %%
# Simple pair plot

g = sns.pairplot(hue="species",
               data=penguins2,
               palette=['#FF8C00','#159090','#A034F0'])

# %%
# Bill depth v Bill length
g = sns.pairplot(hue="species",
               data=penguins3,
               palette=['#FF8C00','#159090','#A034F0'])

# %%
# Flipper length v Body mass
data_columns =(penguins7['flipper_length_mm'])
target_column=(penguins7['body_mass_g'])
sns.scatterplot(data=penguins, x=data_columns, y=target_column)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
# Checking the shape of the data for manipulation
data_columns.shape
# Out:
# (333,)

# %%
# Reshaping the data to allow manipulation in linear regression
data_columns = data_columns.values.reshape(-1, 1)

# %%
# Checking the shape of the data for manipulation
data_columns.shape
# Out:
# (333, 1)

# %%
# Checking the shape of the data for manipulation
target_column.shape
# Out:
# (333,)

# %%
target_column
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 5      3650.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 333, dtype: float64

# %%
data_columns = data_columns[:, np.newaxis, 0]

# %%
data_columns
# Out:
# array([[181.],
#        [186.],
#        [195.],
#        [193.],
#        [190.],
#        [181.],
#        [195.],
#        [182.],
#        [191.],
#        [198.],
#        [185.],
#        [195.],
#        [197.],
#        [184.],
#        [194.],
#        [174.],
#        [180.],
#        [189.],
#        [185.],
#        [180.],
#        [187.],
#        [183.],
#        [187.],
#        [172.],
#        [180.],
#        [178.],
#        [178.],
#        [188.],
#        [184.],
#        [195.],
#        [196.],
#        [190.],
#        [180.],
#        [181.],
#        [184.],
#        [182.],
#        [195.],
#        [186.],
#        [196.],
#        [185.],
#        [190.],
#        [182.],
#        [190.],
#        [191.],
#        [186.],
#        [188.],
#        [190.],
#        [200.],
#        [187.],
#        [191.],
#        [186.],
#        [193.],
#        [181.],
#        [194.],
#        [185.],
#        [195.],
#        [185.],
#        [192.],
# ...

# %%
#data_columns_train =data_columns[:-20]
#data_columns_test =data_columns[:-20]

# %%
#target_column_train=target_column[:-20]
#target_column_test=target_column[:-20]

# %%
data_columns_train,data_columns_test,target_column_train,target_column_test=train_test_split(data_columns,target_column,train_size =50,test_size=283)

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(data_columns_train,target_column_train )
# Out:
# LinearRegression()

# %%
target_column_prediction=regr.predict(data_columns_test)

# %%
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [51.88374805]

# %%
print('Mean squared error: %.2f'
% mean_squared_error(target_column_test,target_column_prediction ))
# Out:
# Mean squared error: 157238.56

# %%
# Plot outputs
plt.style.use('ggplot')
plt.rcParams['figure.figsize']=14,10
plt.scatter(data_columns_test,target_column_test ,  color='black')
plt.plot(data_columns_test,target_column_prediction , color='blue', linewidth=3)
plt.xlabel('flipper length in mm')
plt.ylabel('body mass in grams')
plt.title('linear regression using ')

plt.xticks()
plt.yticks()

plt.show()

# %%
penguins5
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
# creation of KNN neighbours field for prediciton

# %%
inputs = penguins7[['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']]
output = penguins7[['species','sex','island']]

# %%
# using 5 for the comparison number
knn =nei.KNeighborsClassifier(n_neighbors=5)

# %%
# calling the knn fit
knn.fit(inputs, output)
# Out:
# KNeighborsClassifier()

# %%
# retrieving penguin 300 for comparison
penguins5.loc[300]
# Out:
# species              Chinstrap
# island                   Dream
# bill_length_mm            46.7
# bill_depth_mm             17.9
# flipper_length_mm        195.0
# body_mass_g             3300.0
# sex                     female
# year                      2007
# Name: 300, dtype: object

# %%
knn.predict([[43.7,18.9,200.0,3150.0]])
# Out:
# array([['Adelie', 'female', 'Biscoe']], dtype=object)

# %%
penguins7
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
from sklearn.neighbors import KDTree
kdt = KDTree(inputs, leaf_size=1, metric='euclidean')
kdt.query(inputs, k=2, return_distance=True)
# Out:
# (array([[  0.        ,  12.08511481],
#         [  0.        ,   3.28633535],
#         [  0.        ,   6.47842573],
#         [  0.        ,   2.596151  ],
#         [  0.        ,   5.35723809],
#         [  0.        ,  25.06491572],
#         [  0.        ,  25.37104649],
#         [  0.        ,   5.0447993 ],
#         [  0.        ,   3.02985148],
#         [  0.        ,   7.34098086],
#         [  0.        ,   2.20227155],
#         [  0.        ,   2.84429253],
#         [  0.        ,  13.62497706],
#         [  0.        ,   7.28422954],
#         [  0.        ,  11.14540264],
#         [  0.        ,  11.17497204],
#         [  0.        ,   5.0049975 ],
#         [  0.        ,   1.11803399],
#         [  0.        ,   4.14969878],
#         [  0.        ,   6.04400529],
#         [  0.        ,   1.40356688],
#         [  0.        ,   1.37840488],
#         [  0.        ,   1.36014705],
#         [  0.        ,  10.11533489],
#         [  0.        ,   5.56147462],
# ...

# %%
import numpy as np
rng = np.random.RandomState()
X = rng.random_sample((10, 1))  # 10 points in 3 dimensions
print(X)
tree = KDTree(X, leaf_size=2)
dist, ind = tree.query(X[:1], k=3)                
print(ind)  # indices of 3 closest neighbors

print(dist)  # distances to 3 closest neighbors
# Out:
# [[0.69080934]
#  [0.49388268]
#  [0.67171042]
#  [0.04319505]
#  [0.89132383]
#  [0.4384144 ]
#  [0.57716831]
#  [0.81402108]
#  [0.3018187 ]
#  [0.17234316]]
# [[0 2 6]]
# [[0.         0.01909892 0.11364103]]
